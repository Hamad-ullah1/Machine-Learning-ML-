# %%
import pandas as pd
import requests

# %%
#Paste the you API Key in {API_KEY} so the code will working
response = requests.get(
    'https://api.themoviedb.org/3/tv/top_rated?api_key={API_KEY}&language=en-US&page=1'
)

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/wh5agdl3b7fqC7mSjsCkHx4fMAs.jpg',
#    'genre_ids': [37, 18],
#    'id': 299167,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Dutton Ranch',
#    'overview': 'Rip Wheeler and Beth Dutton gamble everything on a new life in South Texas, but the promise of building a future far from the ghosts of Yellowstone quickly collides with brutal new realities and a rival ranch that will stop at nothing to protect its empire.',
#    'popularity': 143.0673,
#    'poster_path': '/xsiecCxd8lkcAluw0wWwbW5CwSv.jpg',
#    'first_air_date': '2026-05-15',
#    'softcore': False,
#    'name': 'Dutton Ranch',
#    'vote_average': 9.3,
#    'vote_count': 237},
#   {'adult': False,
#    'backdrop_path': '/52sp0vPhLOWrZ1QoZIWiapronM.jpg',
#    'genre_ids': [18],
#    'id': 273240,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Off Campus',
# ...

# %%
#trying to fetch a specific data

response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/wh5agdl3b7fqC7mSjsCkHx4fMAs.jpg',
#   'genre_ids': [37, 18],
#   'id': 299167,
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_name': 'Dutton Ranch',
#   'overview': 'Rip Wheeler and Beth Dutton gamble everything on a new life in South Texas, but the promise of building a future far from the ghosts of Yellowstone quickly collides with brutal new realities and a rival ranch that will stop at nothing to protect its empire.',
#   'popularity': 143.0673,
#   'poster_path': '/xsiecCxd8lkcAluw0wWwbW5CwSv.jpg',
#   'first_air_date': '2026-05-15',
#   'softcore': False,
#   'name': 'Dutton Ranch',
#   'vote_average': 9.3,
#   'vote_count': 237},
#  {'adult': False,
#   'backdrop_path': '/52sp0vPhLOWrZ1QoZIWiapronM.jpg',
#   'genre_ids': [18],
#   'id': 273240,
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_name': 'Off Campus',
# ...

# %%
#converted list into datafram

pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path               genre_ids      id  \
# 0   False  /wh5agdl3b7fqC7mSjsCkHx4fMAs.jpg                [37, 18]  299167
# 1   False   /52sp0vPhLOWrZ1QoZIWiapronM.jpg                    [18]  273240
# 2   False  /tsRy63Mu5cu8etL1X7ZLyf7UP1M.jpg                [18, 80]    1396
# 3   False  /rBOnrVlck7BIlGeWVlzYiZeg4l2.jpg  [16, 10759, 18, 10765]  209867
# 4   False  /sZH7lGs06skRKkrqp1LRi57VVMb.jpg                    [35]   64010
# 5   False  /7oBGhqJIghRBvOwo5Qe0yM0cnMc.jpg      [16, 10759, 10765]     246
# 6   False  /q8eejQcg1bAqImEV8jh8RtBD4uH.jpg      [16, 10759, 10765]   94605
# 7   False  /7Sgo1XdCrIpJpiNsTPMi9vwKSuC.jpg                    [18]  250307
# 8   False  /2rmK7mnchw9Xr3XdiTFSxTTLXqv.jpg         [10759, 35, 16]   37854
# 9   False  /mwczMJeoQrsPERcyP1e900jo3Jv.jpg                    [18]  219246
# 10  False  /3siv3RaQrdr2tQiv9jHq71sLlzo.jpg      [10759, 10751, 18]   85077
# ...

# %%
temp_df =pd.DataFrame(response.json()['results']).head(2)

# %%
#fetchind specific data which we wanted
df = pd.DataFrame(response.json()['results'])[
    ['id','original_name','overview','original_name',
     'popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#        id original_name                                           overview  \
# 0  299167  Dutton Ranch  Rip Wheeler and Beth Dutton gamble everything ...
# 1  273240    Off Campus  Hannah Wells tutors hockey captain Garrett Gra...
# 2    1396  Breaking Bad  Walter White, a New Mexico chemistry teacher, ...
# 3  209867      葬送のフリーレン  After the party of heroes defeated the Demon K...
# 4   64010     응답하라 1988  Take a nostalgic trip back to the late 1980s t...
#
#   original_name  popularity  vote_average  vote_count
# 0  Dutton Ranch    143.0673         9.300         237
# 1    Off Campus    508.6964         9.000         422
# 2  Breaking Bad    171.4720         8.946       17895
# 3      葬送のフリーレン     64.5506         8.806         844
# 4     응답하라 1988     16.9599         8.800         213

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,124):
    response = requests.get(
        'https://api.themoviedb.org/3/tv/top_rated?api_key={API_KEY}&language=en-US&page=1'.format(i)
    )

    temp_df = pd.DataFrame(response.json()['results'])[
        ['id','original_name','overview','original_name',
         'popularity','vote_average','vote_count']
    ]

    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df

# %%
df.to_csv('movie.csv')
