# %%
import pandas as pd

# %%
# !pip install kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download(
    "kaggle/recipe-ingredients-dataset"
)

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Dir com\.cache\kagglehub\datasets\kaggle\recipe-ingredients-dataset\versions\1

# %%
#seeing folders what is inside
import os

path = r"C:\Users\Dir com\.cache\kagglehub\datasets\kaggle\recipe-ingredients-dataset\versions\1"

print(os.listdir(path))
# Out:
# ['test.json', 'train.json']

# %%
for file in os.listdir(path):
    print(file)
# Out:
# test.json
# train.json

# %%
import pandas as pd

# %% [markdown]
# Working With Json

# %%
df = pd.read_json(os.path.join(
    path,"train.json")
                 )

# %%
df
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
#Working with SQL

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %%
#Please noted that if you do not have 'World' Dataset so it will give you error.
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='',
    database='world'
)

# %%
df = pd.read_sql_query(
    "SELECT * FROM city", conn
)
# Out:
# C:\Users\Dir com\AppData\Local\Temp\ipykernel_6152\2933025036.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(

# %%
print(df.shape)
df.head()
# Out:
# (4079, 5)
#    ID            Name CountryCode       District  Population
# 0   1           Kabul         AFG          Kabol     1780000
# 1   2        Qandahar         AFG       Qandahar      237500
# 2   3           Herat         AFG          Herat      186800
# 3   4  Mazar-e-Sharif         AFG          Balkh      127800
# 4   5       Amsterdam         NLD  Noord-Holland      731200

# %%
#to avoid warnings we use
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_sql_query(
    "SELECT * FROM city WHERE CountryCode = 'USA'", conn
)

print(df)
# Out:
#        ID          Name CountryCode        District  Population
# 0    3793      New York         USA        New York     8008278
# 1    3794   Los Angeles         USA      California     3694820
# 2    3795       Chicago         USA        Illinois     2896016
# 3    3796       Houston         USA           Texas     1953631
# 4    3797  Philadelphia         USA    Pennsylvania     1517550
# ..    ...           ...         ...             ...         ...
# 269  4062       Kenosha         USA       Wisconsin       89447
# 270  4063         Elgin         USA        Illinois       89408
# 271  4064        Odessa         USA           Texas       89293
# 272  4065        Carson         USA      California       89089
# 273  4066    Charleston         USA  South Carolina       89063
#
# [274 rows x 5 columns]

# %%
df = pd.read_sql_query(
    "SELECT CountryCode, Name, Population FROM city", conn
)

print(df)
# Out:
#      CountryCode            Name  Population
# 0            AFG           Kabul     1780000
# 1            AFG        Qandahar      237500
# 2            AFG           Herat      186800
# 3            AFG  Mazar-e-Sharif      127800
# 4            NLD       Amsterdam      731200
# ...          ...             ...         ...
# 4074         PSE      Khan Yunis      123175
# 4075         PSE          Hebron      119401
# 4076         PSE        Jabaliya      113901
# 4077         PSE          Nablus      100231
# 4078         PSE           Rafah       92020
#
# [4079 rows x 3 columns]
